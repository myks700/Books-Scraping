# %%
import pandas as pd
import numpy as np
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
import time
import warnings
warnings.filterwarnings('ignore')
import time
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome(r'chromedriver.exe')
driver.get('https://www.gfxtra31.com/programming-books/')

# %%
books_url = []
Name=[]
URL = []
start = 0
end = 5

for page in range(start, end):
    url = driver.find_elements(By.XPATH, '//div[@class="baslik"]/a')
    for i in url:
        books_url.append(i.get_attribute('href'))
    nxt_btn = driver.find_element(By.XPATH, '/html/body/div[2]/div/div[2]/div[1]/div[1]/div[1]/div/div[25]/a[11]')
    nxt_btn.click()
    time.sleep(2)

# %%
len(books_url)
# Out:
# 120

# %%
for url in books_url:
    driver.get(url)
    time.sleep(2)
   
    try:
        name = driver.find_element(By.XPATH, '/html/body/div[2]/div/div[2]/div[1]/div[1]/div[1]/div/div[1]/div/div[1]/div[1]/a')
        Name.append(name.text)
        url = driver.find_element(By.XPATH, '/html/body/div[2]/div/div[2]/div[1]/div[1]/div[1]/div/div[1]/div/div[1]/div[1]/a')
        URL.append(url.get_attribute('href'))
        
        
    except NoSuchElementException:
        Name.append('_')

# %%
name = pd.DataFrame(Name, columns = ['Product_Name']).head(55)
url =  pd.DataFrame(URL, columns = ['Product_url']).head(55)

# %%
books_data = pd.concat([name, url], axis = 1)
books_data
# Out:
#                                          Product_Name  \
# 0   Python Programming For Beginners: Learn The Ba...
# 1   Think Python: How to Think Like a Computer Sci...
# 2                    Python For Everyone, 3rd Edition
# 3   Python for Kids: A Playful Introduction to Pro...
# 4   Visual Studio 2022 In-Depth: Explore the Fanta...
# 5   Dead Simple Python: Idiomatic Python for the I...
# 6                        The Python Apprentice (2022)
# 7   Python 3: The Comprehensive Guide to Hands-On ...
# 8           Linux All-In-One For Dummies, 7th Edition
# 9     Mastering Visual Studio Code A Beginner's Guide
# 10                   Python Crash Course, 3rd Edition
# 11                 Readings from Programming with C++
# 12  Python Graphics: A Reference for Creating 2D a...
# 13  Practical API Architecture and Development wit...
# 14  Raspberry Pi for Arduino Users: Building IoT a...
# 15  Python in a Nutshell, 4th Edition (Fifth Early...
# ...

# %%
books_data.to_excel("books_data.xlsx")
